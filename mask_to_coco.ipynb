# %%
import os

# %% [markdown]
# ## Move data from drive to colab instance

# %%
import shutil
source_folder = '/content/drive/MyDrive/Projects/DermViz/Synthetic_data/superimposed_segmentation'  # path to your source folder
destination_folder = '/content/superimposed_segmentation'  # destination folder

shutil.copytree(source_folder, destination_folder)
# Out:
# '/content/superimposed_segmentation'

# %% [markdown]
# ## Split data to train, test & val

# %%
source_folder = "/content/superimposed_segmentation"
destination_folder = "/content/segmentation/train"
files = os.listdir("/content/superimposed_segmentation")
length = len(files)
train_len = round(0.8*length)
test_len = round(0.1 * length)
val_len = length - train_len - test_len
for i in range(train_len):
  source_path = os.path.join(source_folder, files[i])
  destination_path = os.path.join(destination_folder, files[i])
  shutil.copy(source_path, destination_path)

destination_folder = "/content/segmentation/test"
for i in range(train_len,(train_len+test_len)):
  source_path = os.path.join(source_folder, files[i])
  destination_path = os.path.join(destination_folder, files[i])
  shutil.copy(source_path, destination_path)

destination_folder = "/content/segmentation/val"
for i in range((train_len+test_len),length):
  source_path = os.path.join(source_folder, files[i])
  destination_path = os.path.join(destination_folder, files[i])
  shutil.copy(source_path, destination_path)

# %% [markdown]
# ## Convert data to COCO format

# %%
import glob
import json
import os
import cv2
import numpy as np
# Label ids of the dataset
category_ids = {
    "lesion": 1
}
# Function to find contours in a binary mask
def find_contours(mask_image):
    gray = cv2.cvtColor(mask_image, cv2.COLOR_BGR2GRAY)
    _, binary_mask = cv2.threshold(gray, 1, 255, cv2.THRESH_BINARY)
    contours, _ = cv2.findContours(binary_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    return contours
# Create a single annotation for a contour
def create_annotation_format(contour, image_id, category_id, annotation_id):
    segmentation = [int(point) for point in contour.flatten()]
    area = cv2.contourArea(contour)
    bbox = cv2.boundingRect(contour)
    annotation = {
        "id": annotation_id,
        "image_id": image_id,
        "category_id": category_id,
        "segmentation": [segmentation],
        "bbox": bbox,
        "area": area,
        "iscrowd": 0
    }
    return annotation
# Create category annotation
def create_category_annotation(category_ids):
    categories = [{"id": id, "name": name} for name, id in category_ids.items()]
    return categories
# Create image annotation
def create_image_annotation(file_name, width, height):
    image_id = file_name.split('.')[0]
    image_annotation = {
        "id": image_id,
        "file_name": file_name,
        "width": width,
        "height": height
    }
    return image_annotation
# Get COCO JSON format
def get_coco_json_format():
    coco_format = {
        "info": {},
        "licenses": [],
        "images": [],
        "annotations": [],
        "categories": []
    }
    return coco_format
# Get "images" and "annotations" info
def images_annotations_info(maskpath):
    annotation_id = 0
    annotations = []
    images = []
    for category in category_ids.keys():
        for mask_image_path in glob.glob(os.path.join(maskpath, f'*.{MASK_EXT}')):
            original_file_name = os.path.basename(mask_image_path).replace('_segmented', '')  # Remove "_segmented"
            mask_image_open = cv2.imread(mask_image_path)
            height, width, c = mask_image_open.shape
            image = create_image_annotation(file_name=original_file_name, width=width, height=height)
            images.append(image)
            contours = find_contours(mask_image_open)
            for contour in contours:
                annotation = create_annotation_format(contour, image['id'], category_ids[category], annotation_id)
                if annotation['area'] > 0:
                    annotations.append(annotation)
                    annotation_id += 1
    return images, annotations, annotation_id
if __name__ == "__main__":
    MASK_EXT = 'jpg'
    ORIGINAL_EXT = 'jpg'
    coco_format = get_coco_json_format()
    for keyword in ["train","test","val"]:
      mask_path = f"/content/segmentation/{keyword}/"
      output_path = f"/content/output/{keyword}.json"
      coco_format["categories"] = create_category_annotation(category_ids)
      coco_format["images"], coco_format["annotations"], annotation_cnt = images_annotations_info(mask_path)
      with open(output_path, "w+") as outfile:
          json.dump(coco_format, outfile, sort_keys=True, indent=4)
      print(f"Created {annotation_cnt} annotations for images in folder: {mask_path}")
      print(f"Saved COCO data to: {output_path}")
      # Print the list of mask images being processed
      mask_images = glob.glob(os.path.join(mask_path, f'*.{MASK_EXT}'))
      print(f"Mask images found in folder: {mask_images}")
# Out:
# Created 90488 annotations for images in folder: /content/segmentation/train/
# Saved COCO data to: /content/output/train.json
# Mask images found in folder: ['/content/segmentation/train/U16_2009_01_12_scaled_1_4_segmented.jpg', '/content/segmentation/train/05_2008_flipped_5_segmented.jpg', '/content/segmentation/train/F16_2010_10_11_scaled_0_2_segmented.jpg', '/content/segmentation/train/U16_2009_01_12_Regist_scaled_1_0_segmented.jpg', '/content/segmentation/train/U16_2005_10_31_Regist_flipped_5_segmented.jpg', '/content/segmentation/train/H14_2009_12_09_Regist_flipped_0_segmented.jpg', '/content/segmentation/train/21_2009_flipped_4_segmented.jpg', '/content/segmentation/train/N16_2006_04_17_Regist_2_segmented.jpg', '/content/segmentation/train/05_2003_scaled_0_1_segmented.jpg', '/content/segmentation/train/20_2008_scaled_0_3_segmented.jpg', '/content/segmentation/train/O14_2015_10_12_scaled_0_2_segmented.jpg', '/content/segmentation/train/N16_2010_07_09_3_segmented.jpg', '/content/segmentation/train/Q16_2009_01_26_Regist_7_segmented.jpg', '/content/segmentation/train/F14_2010_10_11_Regist_3_segmented.jpg', '/content/segmentation/train/05_2008_flipped_2_segmented.jpg', '/content/segmentation/train/G16_2010_07_12_scaled_0_9_segmented.jpg', '/content/segmentation/train/08_2012_LLPT_scaled_0_8_segmented.jpg', '/content/segmentation/train/24_2009_scaled_0_8_segmented.jpg', '/content/segmentation/train/N16_2010_07_09_scaled_1_6_segmented.jpg', '/content/segmentation/train/T16_2008_10_06_Regist_7_segmented.jpg', '/content/segmentation/train/T16_2011_06_13_scaled_1_0_segmented.jpg', '/content/segmentation/train/S16_2010_09_13_flipped_9_segmented.jpg', '/content/segmentation/train/08_2012_LLPT_flipped_3_segmented.jpg', '/content/segmentation/train/F16_2007_02_15_Regist_scaled_1_5_segmented.jpg', '/content/segmentation/train/08_2012_PT_scaled_1_7_segmented.jpg', '/content/segmentation/train/U16_2005_10_31_Regist_4_segmented.jpg', '/content/segmentation/train/Q16_2012_04_03_scaled_1_5_segmented.jpg', '/content/segmentation/train/24_2009_scaled_1_5_segmented.jpg', '/content/segmentation/train/F14_2010_10_11_Regist_scaled_1_6_segmented.jpg', '/content/segmentation/train/A16_2010_03_08_scaled_0_2_segmented.jpg', '/content/segmentation/train/T16_2008_10_06_Regist_scaled_1_7_segmented.jpg', '/content/segmentation/train/O16_2005_12_12_scaled_0_2_segmented.jpg', '/content/segmentation/train/U16_2005_10_31_Regist_scaled_0_4_segmented.jpg', '/content/segmentation/train/O16_2005_06_27_Regist_flipped_5_segmented.jpg', '/content/segmentation/train/H14_2009_12_09_Regist_flipped_9_segmented.jpg', '/content/segmentation/train/G16_2010_07_12_flipped_7_segmented.jpg', '/content/segmentation/train/F14_2010_10_11_Regist_flipped_3_segmented.jpg', '/content/segmentation/train/G16_2010_07_12_scaled_1_0_segmented.jpg', '/content/segmentation/train/22_2002_flipped_2_segmented.jpg', '/content/segmentation/train/24_2006_scaled_1_1_segmented.jpg', '/content/segmentation/train/H14_2009_12_09_Regist_scaled_0_4_segmented.jpg', '/content/segmentation/train/J16_2009_05_04_scaled_0_9_segmented.jpg', '/content/segmentation/train/Q16_2012_04_03_0_segmented.jpg', '/content/segmentation/train/E16_2003_10_16_Regist_scaled_0_8_segmented.jpg', '/content/segmentation/train/N16_2006_04_17_Regist_0_segmented.jpg', '/content/segmentation/train/Z16_2020_12_30_Regist_8_segmented.jpg', '/content/segmentation/train/14_2006_scaled_0_2_segmented.jpg', '/content/segmentation/train/L16_2009_12_14_flipped_4_segmented.jpg', '/content/segmentation/train/D16_2005_08_08_Regist_scaled_0_5_segmented.jpg', '/content/segmentation/train/Q16_2009_01_26_Regist_5_segmented.jpg', '/content/segmentation/train/20_2008_scaled_1_2_segmented.jpg', '/content/segmentation/train/O14_2010_03_08_Regist_2_segmented.jpg', '/content/segmentation/train/05_2003_scaled_0_7_segmented.jpg', '/content/segmentation/train/05_2003_scaled_1_6_segmented.jpg', '/content/segmentation/train/20_2011_flipped_0_segmented.jpg', '/content/segmentation/train/S16_2010_09_13_scaled_1_6_segmented.jpg', '/content/segmentation/train/20_2008_flipped_5_segmented.jp ...
# Created 11540 annotations for images in folder: /content/segmentation/test/
# Saved COCO data to: /content/output/test.json
# Mask images found in folder: ['/content/segmentation/test/L16_2009_12_14_0_segmented.jpg', '/content/segmentation/test/U16_2009_01_12_Regist_flipped_7_segmented.jpg', '/content/segmentation/test/08_2012_LLPT_scaled_0_5_segmented.jpg', '/content/segmentation/test/S16_2008_05_05_Regist_scaled_0_3_segmented.jpg', '/content/segmentation/test/21_2011_8_segmented.jpg', '/content/segmentation/test/H14_2009_12_09_Regist_4_segmented.jpg', '/content/segmentation/test/L16_2007_06_18_Regist_0_segmented.jpg', '/content/segmentation/test/20_2008_flipped_3_segmented.jpg', '/content/segmentation/test/D16_2005_08_08_Regist_flipped_3_segmented.jpg', '/content/segmentation/test/F14_2010_10_11_Regist_0_segmented.jpg', '/content/segmentation/test/U16_2011_02_14_flipped_4_segmented.jpg', '/content/segmentation/test/06_2007_3_segmented.jpg', '/content/segmentation/test/21_2009_flipped_8_segmented.jpg', '/content/segmentation/test/U16_2009_01_12_flipped_8_segmented.jpg', '/content/segmentation/test/23_2007_flipped_8_segmented.jpg', '/content/segmentation/test/G16_2010_07_12_0_segmented.jpg', '/content/segmentation/test/L16_2007_06_18_Regist_scaled_0_1_segmented.jpg', '/content/segmentation/test/10_2007_scaled_1_7_segmented.jpg', '/content/segmentation/test/18_2008_scaled_1_4_segmented.jpg', '/content/segmentation/test/14_2006_6_segmented.jpg', '/content/segmentation/test/G16_2010_07_12_1_segmented.jpg', '/content/segmentation/test/22_2011_scaled_0_5_segmented.jpg', '/content/segmentation/test/06_2007_scaled_1_9_segmented.jpg', '/content/segmentation/test/21_2005_7_segmented.jpg', '/content/segmentation/test/J16_2009_05_04_1_segmented.jpg', '/content/segmentation/test/G16_2010_07_12_scaled_1_4_segmented.jpg', '/content/segmentation/test/T16_2011_06_13_scaled_0_7_segmented.jpg', '/content/segmentation/test/10_2007_flipped_6_segmented.jpg', '/content/segmentation/test/18_2008_scaled_0_5_segmented.jpg', '/content/segmentation/test/10_2007_scaled_0_3_segmented.jpg', '/content/segmentation/test/22_2002_3_segmented.jpg', '/content/segmentation/test/R16_2005_09_19_Regist_4_segmented.jpg', '/content/segmentation/test/J16_2007_01_29_Regist_scaled_0_5_segmented.jpg', '/content/segmentation/test/K16_2003_10_20_Regist_scaled_0_3_segmented.jpg', '/content/segmentation/test/U16_2011_02_14_flipped_0_segmented.jpg', '/content/segmentation/test/S16_2008_05_05_Regist_flipped_9_segmented.jpg', '/content/segmentation/test/L16_2007_06_18_Regist_scaled_1_1_segmented.jpg', '/content/segmentation/test/10_2007_flipped_2_segmented.jpg', '/content/segmentation/test/F16_2010_10_11_scaled_1_4_segmented.jpg', '/content/segmentation/test/H14_2009_12_09_Regist_1_segmented.jpg', '/content/segmentation/test/03_2003_scaled_0_3_segmented.jpg', '/content/segmentation/test/23_2007_1_segmented.jpg', '/content/segmentation/test/L16_2009_12_14_flipped_9_segmented.jpg', '/content/segmentation/test/N16_2010_07_09_scaled_0_4_segmented.jpg', '/content/segmentation/test/05_2003_0_segmented.jpg', '/content/segmentation/test/05_2008_9_segmented.jpg', '/content/segmentation/test/05_2003_scaled_0_5_segmented.jpg', '/content/segmentation/test/H14_2009_12_09_Regist_scaled_0_1_segmented.jpg', '/content/segmentation/test/U16_2009_01_12_Regist_2_segmented.jpg', '/content/segmentation/test/20_2008_flipped_1_segmented.jpg', '/content/segmentation/test/S16_2008_05_05_Regist_3_segmented.jpg', '/content/segmentation/test/06_2007_scaled_1_4_segmented.jpg', '/content/segmentation/test/23_2007_scaled_1_5_segmented.jpg', '/content/segmentation/test/08_2012_PT_flipped_4_segmented.jpg', '/content/segmentation/test/T16_2011_06_13_2_segmented.jpg', '/content/segmentation/test/Z16_2020_12_30_Regist_scaled_1_0_segmented.jpg', '/content/segmentation/test/D16_2009_04_06_scaled_0_0_segmented.jpg', '/content/segmentation/test/O16_2005_12_12_scaled_0_4_segmented.jpg', '/content/segmentation/test/S16_2010_09_13_scaled_1_8_segmented.jpg', '/content/segmentation/test/15_2005_scaled_1_1_segmented.jpg', '/content/segmentation/tes ...
# Created 10813 annotations for images in folder: /content/segmentation/val/
# Saved COCO data to: /content/output/val.json
# Mask images found in folder: ['/content/segmentation/val/N16_2006_04_17_Regist_3_segmented.jpg', '/content/segmentation/val/Z16_2020_12_30_Regist_flipped_8_segmented.jpg', '/content/segmentation/val/S16_2010_09_13_7_segmented.jpg', '/content/segmentation/val/08_2012_PT_6_segmented.jpg', '/content/segmentation/val/23_2007_scaled_1_0_segmented.jpg', '/content/segmentation/val/A16_2010_03_08_scaled_0_6_segmented.jpg', '/content/segmentation/val/E16_2003_10_16_Regist_scaled_0_7_segmented.jpg', '/content/segmentation/val/20_2011_scaled_0_6_segmented.jpg', '/content/segmentation/val/21_2011_flipped_0_segmented.jpg', '/content/segmentation/val/08_2012_PT_scaled_1_3_segmented.jpg', '/content/segmentation/val/H14_2012_06_05_flipped_3_segmented.jpg', '/content/segmentation/val/24_2006_scaled_0_6_segmented.jpg', '/content/segmentation/val/06_2010_scaled_0_8_segmented.jpg', '/content/segmentation/val/19_2010png_scaled_1_7_segmented.jpg', '/content/segmentation/val/L16_2009_12_14_6_segmented.jpg', '/content/segmentation/val/10_2007_scaled_0_4_segmented.jpg', '/content/segmentation/val/14_2010_scaled_1_8_segmented.jpg', '/content/segmentation/val/06_2016_9_segmented.jpg', '/content/segmentation/val/21_2005_0_segmented.jpg', '/content/segmentation/val/E16_2008_04_07_flipped_5_segmented.jpg', '/content/segmentation/val/L16_2007_06_18_Regist_flipped_7_segmented.jpg', '/content/segmentation/val/21_2009_scaled_1_5_segmented.jpg', '/content/segmentation/val/13_2006_6_segmented.jpg', '/content/segmentation/val/08_2012_PT_scaled_0_3_segmented.jpg', '/content/segmentation/val/E16_2003_10_16_Regist_3_segmented.jpg', '/content/segmentation/val/21_2005_3_segmented.jpg', '/content/segmentation/val/T16_2011_06_13_scaled_0_1_segmented.jpg', '/content/segmentation/val/23_2007_flipped_1_segmented.jpg', '/content/segmentation/val/21_2009_scaled_1_6_segmented.jpg', '/content/segmentation/val/21_2009_scaled_0_1_segmented.jpg', '/content/segmentation/val/22_2002_scaled_1_8_segmented.jpg', '/content/segmentation/val/U16_2009_01_12_scaled_0_6_segmented.jpg', '/content/segmentation/val/U16_2005_10_31_Regist_flipped_3_segmented.jpg', '/content/segmentation/val/L16_2007_06_18_Regist_scaled_0_8_segmented.jpg', '/content/segmentation/val/10_2007_flipped_5_segmented.jpg', '/content/segmentation/val/24_2006_flipped_3_segmented.jpg', '/content/segmentation/val/R16_2008_12_22_scaled_0_7_segmented.jpg', '/content/segmentation/val/N16_2006_04_17_Regist_flipped_6_segmented.jpg', '/content/segmentation/val/O16_2005_12_12_flipped_4_segmented.jpg', '/content/segmentation/val/N16_2010_07_09_5_segmented.jpg', '/content/segmentation/val/Z16_2021_06_30_scaled_1_8_segmented.jpg', '/content/segmentation/val/E16_2003_10_16_Regist_9_segmented.jpg', '/content/segmentation/val/O14_2010_03_08_Regist_scaled_1_4_segmented.jpg', '/content/segmentation/val/Q16_2009_01_26_Regist_scaled_1_8_segmented.jpg', '/content/segmentation/val/U16_2009_01_12_Regist_scaled_1_8_segmented.jpg', '/content/segmentation/val/F16_2007_02_15_Regist_scaled_1_2_segmented.jpg', '/content/segmentation/val/A16_2010_03_08_flipped_3_segmented.jpg', '/content/segmentation/val/L16_2007_06_18_Regist_flipped_2_segmented.jpg', '/content/segmentation/val/19_2008_scaled_1_2_segmented.jpg', '/content/segmentation/val/O16_2005_06_27_Regist_scaled_1_1_segmented.jpg', '/content/segmentation/val/L16_2009_12_14_5_segmented.jpg', '/content/segmentation/val/20_2008_flipped_0_segmented.jpg', '/content/segmentation/val/K16_2011_01_10_2_segmented.jpg', '/content/segmentation/val/S16_2010_09_13_scaled_0_5_segmented.jpg', '/content/segmentation/val/08_2012_PT_scaled_0_5_segmented.jpg', '/content/segmentation/val/E16_2003_10_16_Regist_0_segmented.jpg', '/content/segmentation/val/Z16_2020_12_30_Regist_scaled_1_7_segmented.jpg', '/content/segmentation/val/F14_2016_09_09_scaled_1_7_segmented.jpg', '/content/segmentation/val/N16_2010_07_09_9_segmented.jpg', '/content/segmentation/val/08_2012_LLPT_scaled_1_4_segmented.jpg', '/content/segmentation ...
