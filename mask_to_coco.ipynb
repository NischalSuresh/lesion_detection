# %% [markdown]
# <a href="https://colab.research.google.com/github/NischalSuresh/lesion_detection/blob/main/mask_to_coco.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

# %% [markdown]
# ## Move data from drive to colab instance

# %%
import shutil
source_folder = '/content/drive/MyDrive/Projects/DermViz/Synthetic_data/superimposed_back'  # path to your source folder
destination_folder = '/content/superimposed_back'  # destination folder
shutil.copytree(source_folder, destination_folder)
# Out:
# '/content/superimposed_back'

# %%
# !zip -r /content/images.zip /content/superimposed_back

# %%
import shutil
source_folder = '/content/drive/MyDrive/Projects/DermViz/Synthetic_data/superimposed_segmentation'  # path to your source folder
destination_folder = '/content/superimposed_segmentation'  # destination folder
shutil.copytree(source_folder, destination_folder)
# Out:
# '/content/superimposed_segmentation'

# %%
# !zip -r /content/masks.zip /content/superimposed_segmentation

# %% [markdown]
# ## move zip files to drive

# %%
source_path = '/content/images.zip'
destination_path = '/content/drive/MyDrive/Projects/DermViz/Synthetic_data/full_back_syn/'
shutil.copy(source_path, destination_path)
# Out:
# '/content/drive/MyDrive/Projects/DermViz/Synthetic_data/full_back_syn/images.zip'

# %%
source_path = '/content/masks.zip'
destination_path = '/content/drive/MyDrive/Projects/DermViz/Synthetic_data/full_back_syn/'
shutil.copy(source_path, destination_path)
# Out:
# '/content/drive/MyDrive/Projects/DermViz/Synthetic_data/full_back_syn/masks.zip'

# %% [markdown]
# ## renamed the segmentation images to remove "_segmented"

# %%
dir = "/content/superimposed_segmentation"
files_dir = os.listdir(dir)
for old_filename in files_dir:
    if old_filename.endswith('_segmented.jpg'):
        new_filename = old_filename.replace('_segmented', '')
        old_path = os.path.join(dir, old_filename)
        new_path = os.path.join(dir, new_filename)
        os.rename(old_path, new_path)

# %% [markdown]
# ## sanity check if masks and images folder are the same

# %%
source_folder_images = "/content/superimposed_back"
source_folder_masks = "/content/superimposed_segmentation"
files_images = sorted(os.listdir(source_folder_images))
files_masks = sorted(os.listdir(source_folder_masks))
if files_images == files_masks:
    print("Great! The lists are identical")
else:
    print("Check input!! The lists are NOT identical")
# Out:
# Great! The lists are identical

# %% [markdown]
# ## Split data to train, test & val

# %%
source_folder_images = "/content/superimposed_back"
source_folder_masks = "/content/superimposed_segmentation"
files = sorted(os.listdir(source_folder_images))
length = len(files)
train_len = round(0.8*length)
test_len = round(0.1 * length)
val_len = length - train_len - test_len

# train split
destination_folder_images = "/content/images/train"
destination_folder_masks = '/content/masks/train'
for i in range(train_len):
  #images
  source_path = os.path.join(source_folder_images, files[i])
  destination_path = os.path.join(destination_folder_images, files[i])
  shutil.copy(source_path, destination_path)
  #masks
  source_path = os.path.join(source_folder_masks, files[i])
  destination_path = os.path.join(destination_folder_masks, files[i])
  shutil.copy(source_path, destination_path)

# test split
destination_folder_images = "/content/images/test"
destination_folder_masks = '/content/masks/test'
for i in range(train_len,(train_len+test_len)):
  #images
  source_path = os.path.join(source_folder_images, files[i])
  destination_path = os.path.join(destination_folder_images, files[i])
  shutil.copy(source_path, destination_path)
  #masks
  source_path = os.path.join(source_folder_masks, files[i])
  destination_path = os.path.join(destination_folder_masks, files[i])
  shutil.copy(source_path, destination_path)

# val split
destination_folder_images = "/content/images/val"
destination_folder_masks = '/content/masks/val'
for i in range((train_len+test_len),length):
  #images
  source_path = os.path.join(source_folder_images, files[i])
  destination_path = os.path.join(destination_folder_images, files[i])
  shutil.copy(source_path, destination_path)
  #masks
  source_path = os.path.join(source_folder_masks, files[i])
  destination_path = os.path.join(destination_folder_masks, files[i])
  shutil.copy(source_path, destination_path)

# %% [markdown]
# ## sanity check if masks and images folder are the same in train test and val splits

# %%
for val in {'train','test','val'}:
  source_folder_images = "/content/images/" + val
  source_folder_masks = "/content/masks/" + val
  files_images = sorted(os.listdir(source_folder_images))
  files_masks = sorted(os.listdir(source_folder_masks))
  if files_images == files_masks:
      print("Great! The lists are identical")
  else:
      print("Check input!! The lists are NOT identical")
# Out:
# Great! The lists are identical
# Great! The lists are identical
# Great! The lists are identical

# %% [markdown]
# ## zip move masks and images to drive

# %%
# !zip -r /content/drive/MyDrive/Projects/DermViz/Synthetic_data/full_back_syn/masks_split.zip /content/masks
# !zip -r /content/drive/MyDrive/Projects/DermViz/Synthetic_data/full_back_syn/images_split.zip /content/images

# %% [markdown]
# ## Convert data to COCO format

# %%
import glob
import json
import os
import cv2
import numpy as np
# Label ids of the dataset
category_ids = {
    "lesion": 1
}
# Function to find contours in a binary mask
def find_contours(mask_image):
    gray = cv2.cvtColor(mask_image, cv2.COLOR_BGR2GRAY)
    _, binary_mask = cv2.threshold(gray, 1, 255, cv2.THRESH_BINARY)
    contours, _ = cv2.findContours(binary_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    return contours
# Create a single annotation for a contour
def create_annotation_format(contour, image_id, category_id, annotation_id):
    segmentation = [int(point) for point in contour.flatten()]
    area = cv2.contourArea(contour)
    bbox = cv2.boundingRect(contour)
    annotation = {
        "id": annotation_id,
        "image_id": image_id,
        "category_id": category_id,
        "segmentation": [segmentation],
        "bbox": bbox,
        "area": area,
        "iscrowd": 0
    }
    return annotation
# Create category annotation
def create_category_annotation(category_ids):
    categories = [{"id": id, "name": name} for name, id in category_ids.items()]
    return categories
# Create image annotation
def create_image_annotation(file_name, width, height):
    image_id = file_name.split('.')[0]
    image_annotation = {
        "id": image_id,
        "file_name": file_name,
        "width": width,
        "height": height
    }
    return image_annotation
# Get COCO JSON format
def get_coco_json_format():
    coco_format = {
        "info": {},
        "licenses": [],
        "images": [],
        "annotations": [],
        "categories": []
    }
    return coco_format
# Get "images" and "annotations" info
def images_annotations_info(maskpath):
    annotation_id = 0
    annotations = []
    images = []
    for category in category_ids.keys():
        for mask_image_path in glob.glob(os.path.join(maskpath, f'*.{MASK_EXT}')):
            original_file_name = os.path.basename(mask_image_path) #.replace('_segmented', '')  # Remove "_segmented"
            mask_image_open = cv2.imread(mask_image_path)
            height, width, c = mask_image_open.shape
            image = create_image_annotation(file_name=original_file_name, width=width, height=height)
            images.append(image)
            contours = find_contours(mask_image_open)
            for contour in contours:
                annotation = create_annotation_format(contour, image['id'], category_ids[category], annotation_id)
                if annotation['area'] > 0:
                    annotations.append(annotation)
                    annotation_id += 1
    return images, annotations, annotation_id
if __name__ == "__main__":
    MASK_EXT = 'jpg'
    ORIGINAL_EXT = 'jpg'
    coco_format = get_coco_json_format()
    for keyword in ["train","test","val"]:
      mask_path = f"/content/masks/{keyword}/"
      output_path = f"/content/jsons_{keyword}.json"
      coco_format["categories"] = create_category_annotation(category_ids)
      coco_format["images"], coco_format["annotations"], annotation_cnt = images_annotations_info(mask_path)
      with open(output_path, "w+") as outfile:
          json.dump(coco_format, outfile, sort_keys=True, indent=4)
      print(f"Created {annotation_cnt} annotations for images in folder: {mask_path}")
      print(f"Saved COCO data to: {output_path}")
      # Print the list of mask images being processed
      mask_images = glob.glob(os.path.join(mask_path, f'*.{MASK_EXT}'))
      print(f"Mask images found in folder: {mask_images}")
# Out:
# Created 89701 annotations for images in folder: /content/masks/train/
# Saved COCO data to: /content/jsons_train.json
# Mask images found in folder: ['/content/masks/train/07_2003_flipped_3.jpg', '/content/masks/train/H14_2009_12_09_Regist_flipped_5.jpg', '/content/masks/train/O14_2010_03_08_Regist_1.jpg', '/content/masks/train/22_2011_flipped_9.jpg', '/content/masks/train/20_2008_scaled_0_8.jpg', '/content/masks/train/18_2008_9.jpg', '/content/masks/train/08_2012_PT_scaled_0_4.jpg', '/content/masks/train/G16_2010_07_12_scaled_0_7.jpg', '/content/masks/train/24_2009_scaled_0_6.jpg', '/content/masks/train/21_2009_scaled_1_0.jpg', '/content/masks/train/Q16_2009_01_26_Regist_flipped_2.jpg', '/content/masks/train/19_2008_scaled_0_4.jpg', '/content/masks/train/19_2010png_flipped_1.jpg', '/content/masks/train/21_2011_scaled_0_2.jpg', '/content/masks/train/N16_2010_07_09_flipped_0.jpg', '/content/masks/train/J16_2009_05_04_scaled_1_1.jpg', '/content/masks/train/F14_2016_09_09_scaled_1_9.jpg', '/content/masks/train/Q16_2009_01_26_Regist_flipped_7.jpg', '/content/masks/train/03_2003_3.jpg', '/content/masks/train/24_2006_0.jpg', '/content/masks/train/21_2011_scaled_1_0.jpg', '/content/masks/train/07_2003_scaled_1_1.jpg', '/content/masks/train/24_2009_scaled_0_4.jpg', '/content/masks/train/A16_2007_04_06_Regist_flipped_3.jpg', '/content/masks/train/23_2007_flipped_5.jpg', '/content/masks/train/J16_2007_01_29_Regist_scaled_1_2.jpg', '/content/masks/train/20_2011_scaled_0_6.jpg', '/content/masks/train/G16_2010_07_12_3.jpg', '/content/masks/train/23_2007_scaled_1_1.jpg', '/content/masks/train/G16_2003_03_31_Regist_scaled_0_0.jpg', '/content/masks/train/21_2011_scaled_1_8.jpg', '/content/masks/train/O14_2010_03_08_Regist_scaled_0_4.jpg', '/content/masks/train/13_2006_6.jpg', '/content/masks/train/05_2008_flipped_7.jpg', '/content/masks/train/13_2006_scaled_1_5.jpg', '/content/masks/train/O14_2015_10_12_scaled_1_9.jpg', '/content/masks/train/D16_2005_08_08_Regist_flipped_7.jpg', '/content/masks/train/20_2011_scaled_1_1.jpg', '/content/masks/train/A16_2010_03_08_scaled_1_8.jpg', '/content/masks/train/19_2008_3.jpg', '/content/masks/train/F14_2010_10_11_Regist_scaled_0_6.jpg', '/content/masks/train/L16_2007_06_18_Regist_scaled_1_0.jpg', '/content/masks/train/23_2010_scaled_0_1.jpg', '/content/masks/train/L16_2009_12_14_scaled_1_2.jpg', '/content/masks/train/E16_2008_04_07_scaled_1_6.jpg', '/content/masks/train/F14_2016_09_09_flipped_1.jpg', '/content/masks/train/D16_2005_08_08_Regist_scaled_1_5.jpg', '/content/masks/train/Q16_2009_01_26_Regist_2.jpg', '/content/masks/train/06_2016_9.jpg', '/content/masks/train/A16_2007_04_06_Regist_scaled_0_8.jpg', '/content/masks/train/F14_2010_10_11_Regist_scaled_0_4.jpg', '/content/masks/train/23_2007_scaled_0_7.jpg', '/content/masks/train/N16_2006_04_17_Regist_scaled_1_7.jpg', '/content/masks/train/Q16_2009_01_26_Regist_flipped_0.jpg', '/content/masks/train/14_2006_6.jpg', '/content/masks/train/14_2010_scaled_1_2.jpg', '/content/masks/train/F14_2010_10_11_Regist_scaled_1_3.jpg', '/content/masks/train/L16_2009_12_14_scaled_1_4.jpg', '/content/masks/train/N16_2010_07_09_8.jpg', '/content/masks/train/14_2006_scaled_0_8.jpg', '/content/masks/train/13_2006_scaled_0_7.jpg', '/content/masks/train/J16_2009_05_04_flipped_6.jpg', '/content/masks/train/K16_2003_10_20_Regist_scaled_0_8.jpg', '/content/masks/train/22_2002_scaled_1_5.jpg', '/content/masks/train/F16_2007_02_15_Regist_scaled_0_1.jpg', '/content/masks/train/06_2007_scaled_1_3.jpg', '/content/masks/train/F14_2010_10_11_Regist_5.jpg', '/content/masks/train/D16_2005_08_08_Regist_scaled_0_4.jpg', '/content/masks/train/24_2009_scaled_1_9.jpg', '/content/masks/train/G16_2003_03_31_Regist_scaled_0_9.jpg', '/content/masks/train/K16_2011_01_10_8.jpg', '/content/masks/train/O14_2010_03_08_Regist_scaled_0_7.jpg', '/content/masks/train/D16_2009_04_06_4.jpg', '/content/masks/train/24_2009_flipped_3.jpg', '/content/masks/train/22_2002_scaled_0_9.jpg', '/content/masks/train/13_2006_scaled_0_0.jpg', '/content/masks/train/05_2003_flipped_2.jpg', '/content/masks/train/O16_2005_12_12_scaled_1_ ...
# Created 11554 annotations for images in folder: /content/masks/test/
# Saved COCO data to: /content/jsons_test.json
# Mask images found in folder: ['/content/masks/test/S16_2010_09_13_scaled_1_5.jpg', '/content/masks/test/T16_2011_06_13_scaled_0_1.jpg', '/content/masks/test/R16_2005_09_19_Regist_flipped_4.jpg', '/content/masks/test/S16_2010_09_13_3.jpg', '/content/masks/test/S16_2008_05_05_Regist_flipped_6.jpg', '/content/masks/test/S16_2008_05_05_Regist_scaled_1_9.jpg', '/content/masks/test/R16_2008_12_22_8.jpg', '/content/masks/test/S16_2010_09_13_scaled_1_1.jpg', '/content/masks/test/T16_2008_10_06_Regist_scaled_0_3.jpg', '/content/masks/test/T16_2008_10_06_Regist_scaled_0_5.jpg', '/content/masks/test/R16_2008_12_22_3.jpg', '/content/masks/test/T16_2008_10_06_Regist_flipped_7.jpg', '/content/masks/test/R16_2008_12_22_scaled_1_8.jpg', '/content/masks/test/S16_2010_09_13_scaled_1_4.jpg', '/content/masks/test/T16_2011_06_13_4.jpg', '/content/masks/test/U16_2005_10_31_Regist_6.jpg', '/content/masks/test/T16_2011_06_13_flipped_8.jpg', '/content/masks/test/T16_2008_10_06_Regist_8.jpg', '/content/masks/test/U16_2005_10_31_Regist_2.jpg', '/content/masks/test/S16_2010_09_13_flipped_1.jpg', '/content/masks/test/S16_2008_05_05_Regist_2.jpg', '/content/masks/test/U16_2005_10_31_Regist_flipped_6.jpg', '/content/masks/test/R16_2005_09_19_Regist_1.jpg', '/content/masks/test/R16_2008_12_22_scaled_0_3.jpg', '/content/masks/test/T16_2011_06_13_flipped_4.jpg', '/content/masks/test/S16_2010_09_13_scaled_1_9.jpg', '/content/masks/test/S16_2010_09_13_scaled_1_0.jpg', '/content/masks/test/T16_2011_06_13_scaled_0_3.jpg', '/content/masks/test/T16_2008_10_06_Regist_2.jpg', '/content/masks/test/R16_2005_09_19_Regist_9.jpg', '/content/masks/test/S16_2008_05_05_Regist_scaled_0_6.jpg', '/content/masks/test/R16_2005_09_19_Regist_flipped_0.jpg', '/content/masks/test/T16_2008_10_06_Regist_scaled_1_5.jpg', '/content/masks/test/S16_2010_09_13_scaled_0_2.jpg', '/content/masks/test/S16_2008_05_05_Regist_scaled_1_4.jpg', '/content/masks/test/U16_2005_10_31_Regist_scaled_1_0.jpg', '/content/masks/test/S16_2010_09_13_scaled_1_2.jpg', '/content/masks/test/T16_2008_10_06_Regist_7.jpg', '/content/masks/test/Q16_2012_04_03_scaled_1_4.jpg', '/content/masks/test/R16_2005_09_19_Regist_0.jpg', '/content/masks/test/R16_2008_12_22_flipped_8.jpg', '/content/masks/test/R16_2008_12_22_flipped_0.jpg', '/content/masks/test/T16_2008_10_06_Regist_3.jpg', '/content/masks/test/U16_2005_10_31_Regist_flipped_2.jpg', '/content/masks/test/S16_2008_05_05_Regist_scaled_0_5.jpg', '/content/masks/test/R16_2008_12_22_scaled_1_9.jpg', '/content/masks/test/T16_2008_10_06_Regist_scaled_1_6.jpg', '/content/masks/test/T16_2011_06_13_1.jpg', '/content/masks/test/Q16_2012_04_03_scaled_1_6.jpg', '/content/masks/test/S16_2010_09_13_scaled_0_1.jpg', '/content/masks/test/U16_2005_10_31_Regist_flipped_0.jpg', '/content/masks/test/U16_2005_10_31_Regist_scaled_0_2.jpg', '/content/masks/test/U16_2005_10_31_Regist_1.jpg', '/content/masks/test/U16_2005_10_31_Regist_flipped_5.jpg', '/content/masks/test/T16_2008_10_06_Regist_flipped_5.jpg', '/content/masks/test/T16_2008_10_06_Regist_scaled_1_8.jpg', '/content/masks/test/R16_2008_12_22_scaled_1_7.jpg', '/content/masks/test/T16_2011_06_13_flipped_7.jpg', '/content/masks/test/R16_2005_09_19_Regist_scaled_1_6.jpg', '/content/masks/test/U16_2005_10_31_Regist_scaled_1_3.jpg', '/content/masks/test/T16_2008_10_06_Regist_flipped_6.jpg', '/content/masks/test/U16_2005_10_31_Regist_scaled_0_7.jpg', '/content/masks/test/R16_2005_09_19_Regist_8.jpg', '/content/masks/test/R16_2005_09_19_Regist_scaled_0_5.jpg', '/content/masks/test/T16_2011_06_13_scaled_0_5.jpg', '/content/masks/test/S16_2010_09_13_0.jpg', '/content/masks/test/T16_2011_06_13_scaled_1_9.jpg', '/content/masks/test/Q16_2012_04_03_scaled_1_3.jpg', '/content/masks/test/S16_2010_09_13_flipped_5.jpg', '/content/masks/test/Q16_2012_04_03_scaled_1_2.jpg', '/content/masks/test/S16_2010_09_13_1.jpg', '/content/masks/test/T16_2011_06_13_flipped_5.jpg', '/content/masks/test/T16_2011_06_13_flipped_1.jpg', '/content/masks/test/T16_2008_10 ...
# Created 11586 annotations for images in folder: /content/masks/val/
# Saved COCO data to: /content/jsons_val.json
# Mask images found in folder: ['/content/masks/val/U16_2011_02_14_scaled_0_5.jpg', '/content/masks/val/Z16_2020_12_30_Regist_4.jpg', '/content/masks/val/U16_2009_01_12_3.jpg', '/content/masks/val/W16_2007_04_23_Regist_flipped_9.jpg', '/content/masks/val/U16_2009_01_12_Regist_scaled_0_7.jpg', '/content/masks/val/Z16_2020_12_30_Regist_flipped_0.jpg', '/content/masks/val/Z16_2021_06_30_4.jpg', '/content/masks/val/U16_2011_02_14_3.jpg', '/content/masks/val/Z16_2020_12_30_Regist_3.jpg', '/content/masks/val/W16_2010_07_12_scaled_0_0.jpg', '/content/masks/val/W16_2010_07_12_scaled_0_3.jpg', '/content/masks/val/W16_2010_07_12_flipped_8.jpg', '/content/masks/val/U16_2011_02_14_scaled_1_9.jpg', '/content/masks/val/U16_2011_02_14_flipped_4.jpg', '/content/masks/val/W16_2010_07_12_scaled_1_6.jpg', '/content/masks/val/U16_2011_02_14_2.jpg', '/content/masks/val/Z16_2020_12_30_Regist_scaled_0_3.jpg', '/content/masks/val/W16_2007_04_23_Regist_2.jpg', '/content/masks/val/Z16_2020_12_30_Regist_flipped_9.jpg', '/content/masks/val/Z16_2020_12_30_Regist_9.jpg', '/content/masks/val/U16_2011_02_14_scaled_1_4.jpg', '/content/masks/val/U16_2009_01_12_scaled_0_0.jpg', '/content/masks/val/U16_2009_01_12_Regist_scaled_0_3.jpg', '/content/masks/val/U16_2011_02_14_scaled_1_8.jpg', '/content/masks/val/W16_2010_07_12_flipped_1.jpg', '/content/masks/val/W16_2007_04_23_Regist_3.jpg', '/content/masks/val/W16_2007_04_23_Regist_flipped_2.jpg', '/content/masks/val/W16_2010_07_12_scaled_0_4.jpg', '/content/masks/val/W16_2007_04_23_Regist_7.jpg', '/content/masks/val/U16_2009_01_12_Regist_0.jpg', '/content/masks/val/Z16_2020_12_30_Regist_scaled_1_0.jpg', '/content/masks/val/U16_2011_02_14_flipped_2.jpg', '/content/masks/val/U16_2009_01_12_4.jpg', '/content/masks/val/Z16_2020_12_30_Regist_1.jpg', '/content/masks/val/W16_2010_07_12_flipped_3.jpg', '/content/masks/val/Z16_2021_06_30_2.jpg', '/content/masks/val/U16_2009_01_12_Regist_2.jpg', '/content/masks/val/U16_2009_01_12_Regist_scaled_1_2.jpg', '/content/masks/val/U16_2009_01_12_scaled_1_6.jpg', '/content/masks/val/W16_2010_07_12_7.jpg', '/content/masks/val/U16_2009_01_12_Regist_scaled_0_1.jpg', '/content/masks/val/Z16_2021_06_30_flipped_9.jpg', '/content/masks/val/Z16_2020_12_30_Regist_scaled_1_2.jpg', '/content/masks/val/U16_2009_01_12_scaled_0_3.jpg', '/content/masks/val/U16_2009_01_12_Regist_3.jpg', '/content/masks/val/Z16_2020_12_30_Regist_scaled_0_1.jpg', '/content/masks/val/W16_2010_07_12_flipped_6.jpg', '/content/masks/val/W16_2007_04_23_Regist_4.jpg', '/content/masks/val/U16_2009_01_12_7.jpg', '/content/masks/val/Z16_2021_06_30_flipped_3.jpg', '/content/masks/val/U16_2011_02_14_6.jpg', '/content/masks/val/Z16_2021_06_30_scaled_1_8.jpg', '/content/masks/val/U16_2009_01_12_Regist_scaled_1_9.jpg', '/content/masks/val/Z16_2020_12_30_Regist_0.jpg', '/content/masks/val/U16_2009_01_12_Regist_scaled_0_0.jpg', '/content/masks/val/W16_2010_07_12_scaled_1_4.jpg', '/content/masks/val/Z16_2021_06_30_flipped_4.jpg', '/content/masks/val/Z16_2020_12_30_Regist_flipped_6.jpg', '/content/masks/val/U16_2009_01_12_flipped_8.jpg', '/content/masks/val/U16_2009_01_12_Regist_5.jpg', '/content/masks/val/W16_2007_04_23_Regist_scaled_0_2.jpg', '/content/masks/val/Z16_2020_12_30_Regist_6.jpg', '/content/masks/val/W16_2007_04_23_Regist_scaled_0_7.jpg', '/content/masks/val/W16_2010_07_12_scaled_1_2.jpg', '/content/masks/val/W16_2007_04_23_Regist_scaled_0_6.jpg', '/content/masks/val/U16_2009_01_12_Regist_scaled_1_6.jpg', '/content/masks/val/U16_2011_02_14_scaled_1_0.jpg', '/content/masks/val/U16_2011_02_14_scaled_1_6.jpg', '/content/masks/val/W16_2007_04_23_Regist_flipped_6.jpg', '/content/masks/val/W16_2010_07_12_scaled_1_5.jpg', '/content/masks/val/U16_2009_01_12_scaled_0_5.jpg', '/content/masks/val/Z16_2020_12_30_Regist_scaled_0_7.jpg', '/content/masks/val/Z16_2021_06_30_1.jpg', '/content/masks/val/U16_2011_02_14_flipped_6.jpg', '/content/masks/val/W16_2007_04_23_Regist_0.jpg', '/content/masks/val/Z16_2021_06_30_3.jpg', '/content/masks/v ...

# %% [markdown]
# ## Move json files to drive

# %%
shutil.copy("/content/jsons_train.json", "/content/drive/MyDrive/Projects/DermViz/Synthetic_data/full_back_syn/json_files/")
shutil.copy("/content/jsons_test.json", "/content/drive/MyDrive/Projects/DermViz/Synthetic_data/full_back_syn/json_files/")
shutil.copy("/content/jsons_val.json", "/content/drive/MyDrive/Projects/DermViz/Synthetic_data/full_back_syn/json_files/")
# Out:
# '/content/drive/MyDrive/Projects/DermViz/Synthetic_data/full_back_syn/json_files/jsons_val.json'
